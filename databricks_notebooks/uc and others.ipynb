-- %%
%sql
SELECT 
    table_name, 
    table_owner, 
    created, 
    last_altered,
    comment
FROM hj_orders.information_schema.tables
WHERE table_schema = 'gold';

-- %%
DECLARE VARIABLE target_branch STRING DEFAULT 'Itahari';

-- %%
-- Using the variable to query
SELECT * 
FROM hj_orders.gold.branch_sales
WHERE branch = target_branch;

-- %%
-- Updating the variable
SET VARIABLE target_branch = 'Boudha';

-- Run the query again
SELECT * 
FROM hj_orders.gold.branch_sales
WHERE branch = target_branch;

-- %%
-- performing time travel
SELECT * FROM hj_orders.silver.orders_processed VERSION AS OF 2;

-- %%
DESCRIBE HISTORY hj_orders.silver.orders_processed;
